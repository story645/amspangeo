# %% [markdown]
# # Visualization & Data With Pangeo
# ## https://pangeo.io/ (@pangeo_data)
# #### Ryan May (@dopplershift)
# #### Hannah Aizenman (@story645)

# %% [markdown]
# # Thank You!
# * Ryan Abernathy - sponsoring travel for this tutorial
# * NumFocus - umbrella nonprofit for numpy, pandas, xarray, dask, matplotlib, bokeh, scipyl, sklearn, jupyter... most of the core scientific Python stack

# %% [markdown]
# # What is Pangeo?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Pangeo project serves as a coordination point between
# * scientists - https://pangeo.io/quickstart.html
# * software - https://pangeo.io/packages.html
# * computing infrastructure - https://pangeo.io/setup_guides/index.html

# %% [markdown]
# # Why should a scientist get involved?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # How does pangeo help?
# ![image.png](attachment:image.png)

# %% [markdown]
# # Want to talk to pangeo folk?
# ## https://discourse.pangeo.io/
